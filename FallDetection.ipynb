# %% [markdown]
# # Import libraries

# %%
import math
import cv2
import numpy as np
import time
import matplotlib.pyplot as plt
import openpifpaf

# %%
from utils import FeatureExtractor, KeyPoints    #Import FeatureExtractor and KeyPoints class

# %%
featureextractor = FeatureExtractor()    #Create the featureextractor instance of FeatureExtractor class

# %%
video = './/TestData//Fall3.mp4'

# %%
division_method = 'Division'
division_cost = featureextractor.processVideo(video, division_method)
# Out:
# C:\Users\hrayr\OneDrive\Desktop\Intern\Exercises\Fall Detection Paper\FALLDETECTION\Checkpoint2\utils.py:210: RuntimeWarning: Mean of empty slice
#   head_coordinate = np.nanmean(keypoints[:5], axis = 0)   #Get the mean of the head coordinate as one points instead of the five points

# %%
differenceSum_method = 'DifferenceSum'
differenceSum_cost = featureextractor.processVideo(video, differenceSum_method)

# %%
meanDifference_method = 'MeanDifference'
meanDifference_cost = featureextractor.processVideo(video, meanDifference_method)

# %%
differenceMean_method = 'DifferenceMean'
differenceMean_cost = featureextractor.processVideo(video, differenceMean_method)

# %%
costMean_method = 'Mean'
costMean = featureextractor.processVideo(video, costMean_method)

# %%
fig, ax = plt.subplots(2,3, figsize = (20,10))
featureextractor.plot(ax[0,0],division_cost, division_method, 17-6, 25-6)
featureextractor.plot(ax[0,1],differenceSum_cost, differenceSum_method, 17-6, 25-6)
featureextractor.plot(ax[0,2],meanDifference_cost, meanDifference_method, 17-6, 25-6)
featureextractor.plot(ax[1,0],differenceMean_cost, differenceMean_method, 17-6, 25-6)
featureextractor.plot(ax[1,1],costMean,costMean_method, 17-6, 25-6)
ax[1,2].set_visible(False)
